# %%
V = arrow((0,0),(1,2))
W = arrow((0,0),(3,-1))

P = V.plot3d()
Q = W.plot3d()

P+Q
# Out:
# Graphics3d Object

# %%
G = arrow((0,0,0),(24/5,21/5,0))
B = arrow((24/5,21/5,0),(-2.5,-3/5,1))



G+B
# Out:
# Graphics3d Object

# %%
A = matrix(QQ,[[3,-2,0,6],[1,0,-2,8],[1,1,1,9]])
show(A)
# Out:
# [ 3 -2  0  6]
# [ 1  0 -2  8]
# [ 1  1  1  9]

# %%
arrow((0,0,1), (1,1,1))
# Out:
# Graphics3d Object

# %%
BG = matrix(QQ,[[3,-2,0,6],[1,1,1,9]])

RG = matrix(QQ,[[1,0,-2,8],[1,1,1,9]])

# %%
BG.rref()
# x + 2/5t = 24.5
# y + 3/5t = 21/5

BG_A = [2/5,3/2]
BG_A = [24.5,21.5]
# Out:
# [   1    0  2/5 24/5]
# [   0    1  3/5 21/5]
