# %%
var('a1,a2,a3')

M = matrix([[a1*a1,a1*a2,a1*a3],[a1*a1,a2*a2,a2*a3],[a1*a3,a2*a3,a3*a3]])

# %%
show(M)
# Out:
# [ a1^2 a1*a2 a1*a3]
# [ a1^2  a2^2 a2*a3]
# [a1*a3 a2*a3  a3^2]

# %%
show(M^2)
# Out:
# [    a1^4 + a1^3*a2 + a1^2*a3^2 a1^3*a2 + a1*a2^3 + a1*a2*a3^2 a1^3*a3 + a1*a2^2*a3 + a1*a3^3]
# [ a1^4 + a1^2*a2^2 + a1*a2*a3^2     a1^3*a2 + a2^4 + a2^2*a3^2    a1^3*a3 + a2^3*a3 + a2*a3^3]
# [a1^3*a3 + a1^2*a2*a3 + a1*a3^3 a1^2*a2*a3 + a2^3*a3 + a2*a3^3   a1^2*a3^2 + a2^2*a3^2 + a3^4]

# %%
M.det()
# Out:
# 0

# %%
f(t)=0.25*sin(10*t)+sin(t)
    
plot(f,(t,0,10))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
# f(t) = 0.25*sin (10t)+sin(t).
import numpy as np
x = np.linspace(0,8,100)
sample = []
for i in x:
    sample.append(0.25*sin(10*i)+sin(i))
# Out:
# 100
# 50

# %%
from sage.plot.point import Point
plot = []
for i in range(len(x)):
    plot.append([x[i],sample[i]])
list_plot(plot)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
x1 = np.linspace(0,8,50)
sample1 = []
for i in x1:
    sample1.append(0.25*sin(10*i)+sin(i))
print(len(x))
print(len(x1))

plot1 = []
for i in range(len(x1)):
    plot1.append([x1[i],sample1[i]])
list_plot(plot1)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
x2 = np.linspace(0,8,30)
sample2 = []
for i in x2:
    sample2.append(0.25*sin(10*i)+sin(i))
print(len(sample2))

plot2 = []
for i in range(len(x2)):
    plot2.append([x2[i],sample2[i]])
list_plot(plot2)
# Out:
# 30
# Graphics object consisting of 1 graphics primitive

# %%
-sample2[1]+2*sample2[2]-sample2[3]
# Out:
# -0.6284727305099673

# %%
-sample2[2]+2*sample2[3]-sample2[4]
# Out:
# 0.9349533964189971

# %%
-sample1[3]+2*sample1[4]-sample1[5]
# Out:
# 0.1461853957383774

# %%
-sample2[4]+2*sample2[5]-sample2[6]
# Out:
# 0.9815300820178567

# %%
A = matrix(QQ,[[2,-1,0],[-1,2,0],[0,-1,2]])
A
# Out:
# [ 2 -1  0]
# [-1  2  0]
# [ 0 -1  2]

# %%
A.dot_product(A)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-35-0dfee3f9343e> in <module>()
# ----> 1 A.dot_product(A)
#
# /Applications/SageMath-8.5.app/Contents/Resources/sage/local/lib/python2.7/site-packages/sage/structure/element.pyx in sage.structure.element.Element.__getattr__ (build/cythonized/sage/structure/element.c:4647)()
#     487             AttributeError: 'LeftZeroSemigroup_with_category.element_class' object has no attribute 'blah_blah'
#     488         """
# --> 489         return self.getattr_from_category(name)
#     490
#     491     cdef getattr_from_category(self, name):
#
# /Applications/SageMath-8.5.app/Contents/Resources/sage/local/lib/python2.7/site-packages/sage/structure/element.pyx in sage.structure.element.Element.getattr_from_category (build/cythonized/sage/structure/element.c:4756)()
#     500         else:
# ...

# %%
N = 100
K = matrix.toeplitz([2, -1] + [0]*(N-2), [-1] + [0]*(N-2))
res_data = K*vector(sample)
res_plot = []
for i in range(len(res_data)):
    res_plot.append([x[i],res_data[i]])

list_plot(res_plot)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
N = 50
K = matrix.toeplitz([2, -1] + [0]*(N-2), [-1] + [0]*(N-2))
res_data1 = K*vector(sample1)
res_plot1 = []
for i in range(len(res_data1)):
    res_plot1.append([x1[i],res_data1[i]])

list_plot(res_plot1)
# Out:
# Graphics object consisting of 1 graphics primitive
