# %%
P = plot3d(lambda x,y: (2400-15*x-20*y)/30, [-100,100], [-100,100])
Q = plot3d(lambda x,y: 100-x-y, [-100,100], [-100,100])
R = plot(x/2, [-100,100])
P+Q+R
# Out:
# Graphics3d Object

# %%
[[1,2,-1,3],[1,3,1,5],[3,8,4,17]]

[[1,2,-4,-4],[2,5,-9,-10],[3,-2,3,11]]
# Out:
# [[1, 2, -4, -4], [2, 5, -9, -10], [3, -2, 3, 11]]
